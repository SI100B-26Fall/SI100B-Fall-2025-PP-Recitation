# %% [markdown]
# # Recitation 1: Python 环境配置
#
# 按照之前的安装指南，我们已经安装了 uv 和 VSCode，并且在终端用 `uv sync` 同步了依赖。接下来我们将学习如何在 VSCode 中运行 Jupyter Notebook。
#
# 在后面的课程中，我们将使用 VSCode Notebook 插件打开 ipynb 文件进行代码演示，同学们自己也可以使用 Notebook 进行代码编写和调试。
#
# 现在，在页面的上方，有 "+ Code", "+ Markdown" 等按钮的那一菜单栏的最右侧，有一个标识你现在使用的 Kernel 按钮。
#
# 我们要将使用的环境切换到本地创建的 `venv` 虚拟环境，点击那个按钮，然后选择当前目录下的 venv（通常路径是 `./.venv/` 开头），若没有找到，点击 "Select Another Kernel" -> "Python Environments..." -> "Create Python Environment" -> "Select intepreter" -> 然后在接下来的文件选择框中打开 `.venv/bin`，选择 `python` 或者 `python.exe` 即可。
#
# 下面的代码块是一个会输出 "Hello, SI100+" 的代码块，点击代码块左侧的三角形按钮，即可运行代码块。

# %%
# click the run button on the left!
print("Hello, SI100+")

# %% [markdown]
# 如果你看到了 "Hello, SI100+"

# %% [markdown]
# 接下来尝试调用一个我们安装好了的依赖，它能输出一个随机的程序员笑话

# %%
import pyjokes
pyjokes.get_joke()

# %% [markdown]
# 如果你看到笑话正常输出，代表我们的环境配置和依赖同步成功了！
